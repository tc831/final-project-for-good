# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

base_url = 'https://fbref.com/'

scores_url = 'https://fbref.com/en/comps/9/schedule/Premier-League-Scores-and-Fixtures'

browser.visit(scores_url)

time.sleep(1)

# Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 103.0.5060
# Get LATEST chromedriver version for 103.0.5060 google-chrome
# Driver [C:\Users\hk_la\.wdm\drivers\chromedriver\win32\103.0.5060.134\chromedriver.exe] found in cache

# %%
# next_season_comps = soup.find("div", class_='comps')
next_season = soup.find("a", class_="next")
next_season_link = base_url + next_season["href"]
browser.quit()

# %%
table = pd.read_html(next_season_link)

# %%
browser = Browser('chrome', **executable_path, headless=False)    
browser.visit(next_season_link)
next_season_link = browser.html
next_season_link_soup = bs(next_season_link, 'html.parser')
next_season_title = next_season_link_soup.find_all('div', class_='comps')

# %%
next_season_title = next_season_link_soup.find('div', class_='comps')
next_season_title1 = next_season_title.find('h1').text.strip('\t\r\n')

# %%
nxt_season = next_season_title1.split("-")[1].split(" ")[0]
browser.quit()

# %%
upcoming_matches = table[0]
upcoming_matches = upcoming_matches[['Wk', 'Day', 'Date', 'Time', 'Home', 'Away', 'Venue']]

# %%
upcoming_matches= upcoming_matches.dropna()

# %%
upcoming_matches['season'] = nxt_season
upcoming_matches['mod1'] = ''
upcoming_matches['mod2'] = ''
upcoming_matches['mod3'] = ''
upcoming_matches['mod4'] = ''

# %%
upcoming_matches_df = upcoming_matches.iloc[1:]

# %%
upcoming_matches_df = upcoming_matches_df.reset_index(drop=True)

# %%
upcoming_matches_df
# Out:
#        Wk  Day        Date   Time            Home             Away  \
# 0     1.0  Sat  2022-08-06  12:30          Fulham        Liverpool
# 1     1.0  Sat  2022-08-06  15:00       Tottenham      Southampton
# 2     1.0  Sat  2022-08-06  15:00   Newcastle Utd  Nott'ham Forest
# 3     1.0  Sat  2022-08-06  15:00    Leeds United           Wolves
# 4     1.0  Sat  2022-08-06  15:00     Bournemouth      Aston Villa
# ..    ...  ...         ...    ...             ...              ...
# 374  38.0  Sun  2023-05-28  15:00         Everton      Bournemouth
# 375  38.0  Sun  2023-05-28  15:00  Leicester City         West Ham
# 376  38.0  Sun  2023-05-28  15:00     Aston Villa         Brighton
# 377  38.0  Sun  2023-05-28  15:00    Leeds United        Tottenham
# 378  38.0  Sun  2023-05-28  15:00       Brentford  Manchester City
#
#                            Venue season mod1 mod2 mod3 mod4
# 0                 Craven Cottage   2023
# 1      Tottenham Hotspur Stadium   2023
# 2                St. James' Park   2023
# 3                    Elland Road   2023
# 4               Vitality Stadium   2023
# ..                           ...    ...  ...  ...  ...  ...
# 374                Goodison Park   2023
# 375           King Power Stadium   2023
# 376                   Villa Park   2023
# 377                  Elland Road   2023
# 378  Brentford Community Stadium   2023
#
# [379 rows x 12 columns]
